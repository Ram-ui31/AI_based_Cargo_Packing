# %% [markdown]
# # 01 — Setup
#
# Imports and output-directory configuration.
# Run this notebook first; the cells below set `OUTPUT_DIR`, `TRAIN_DIR`, `TEST_DIR` used by the generation and summary notebooks.

# %%
import sys, os
sys.path.insert(0, '..')  # make src/ importable

import numpy as np
import pandas as pd

np.random.seed(42)

# %%
# Local fallback — edit these for your machine.
OUTPUT_DIR = '../good_data'
TRAIN_DIR  = os.path.join(OUTPUT_DIR, 'synthetic_train')
TEST_DIR   = os.path.join(OUTPUT_DIR, 'synthetic_test')
os.makedirs(TRAIN_DIR, exist_ok=True)
os.makedirs(TEST_DIR,  exist_ok=True)
print('Dirs ready.')
print(f'OUTPUT_DIR = {OUTPUT_DIR}')
